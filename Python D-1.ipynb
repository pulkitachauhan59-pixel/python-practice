# %%
print("Hello World")
# Out:
# Hello World

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
2*10
# Out:
# 20

# %%
2**3
# Out:
# 8

# %%
12*12
# Out:
# 144

# %%
14+14/8
# Out:
# 15.75

# %%
type(10)
# Out:
# int

# %%
type(12.6)
# Out:
# float

# %%
type('abc')
# Out:
# str

# %%
type('pulkita')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
eno=10
ename="pc"
esal=1200000
print("the given eno is",eno)
print("the given ename is",ename)
print("the given esal is",esal)
# Out:
# the given eno is 10
# the given ename is pc
# the given esal is 1200000

# %%
a=int(input("enter a value:"))
b=int(input("enter b value:"))
print(type(a))
print(type(b))
print(a+b)
# Out:
# enter a value:10
# enter b value:10
# <class 'int'>
# <class 'int'>
# 20

# %%
eno=int(input("enter employee number:"))
ename=(input("enter employee name:"))
esal=float(input("enter employee salary"))
print("the given eno is",eno)
print("the given ename is",ename)
print("the given esal is",esal)
# Out:
# enter employee number:2
# enter employee name:pc
# enter employee salary500
# the given eno is 2
# the given ename is pc
# the given esal is 500.0

# %%
r=float(input("enter the radius of circle:"))
pi=3.14
area=pi*r*r
print("the area of circle is",area)
# Out:
# enter the radius of circle:5
# the area of circle is 78.5

# %%
l=int(input("enter length of rectangle:"))
b=int(input("enter breath of rectangle:"))
area=l*b
circumference=2*(l+b)
print("the area of rectangle",area)
print("the circumference of rectangle",circumference)
# Out:
# enter length of rectangle:5
# enter breath of rectangle:4
# the area of rectangle 20
# the circumference of rectangle 18

# %%
age=int(input("enter age of person:"))
if age>=18:
  print("eligible for voting")
else:
  print("not eligible for voting")
# Out:
# enter age of person:9
# not eligible for voting

# %%
num=int(input("enter number:"))
if num>0:
   print("positive")
elif num<0:
   print("negative")
else:
   print("zero")
# Out:
# enter number:12
# positive

# %%
_=12
print(_)
# Out:
# 12
